# %%
from sqlalchemy import create_engine, Column, Integer, String, Text, Float, ForeignKey, DECIMAL, TIMESTAMP, text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import declarative_base, relationship, sessionmaker,Session
from datetime import datetime
import time
from dotenv import load_dotenv
import os
from sqlalchemy import MetaData
from concurrent.futures import ThreadPoolExecutor

# %%
load_dotenv()
database_url = os.getenv("DATABASE_URL")

# %%
engine = create_engine(
    database_url,
    echo=False,
)

Base = declarative_base()

metadata = MetaData()
with engine.connect() as connection:
    connection.execute(text("CREATE SCHEMA IF NOT EXISTS urbanpulse"))
    connection.commit()
# Out:
# 2025-03-03 13:22:11,804 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-03-03 13:22:11,806 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-03 13:22:11,987 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-03-03 13:22:11,989 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-03 13:22:12,171 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-03-03 13:22:12,173 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-03 13:22:12,371 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:22:12,373 INFO sqlalchemy.engine.Engine CREATE SCHEMA IF NOT EXISTS urbanpulse
# 2025-03-03 13:22:12,374 INFO sqlalchemy.engine.Engine [generated in 0.00238s] {}
# 2025-03-03 13:22:12,554 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Citizen Table
class Citizen(Base):
    __tablename__ = "citizen"
    __table_args__ = {"schema": "urbanpulse"}
    citizen_id = Column(Integer, primary_key=True, autoincrement=True)
    first_name = Column(String(50))
    last_name = Column(String(50))
    full_name = Column(String(101))
    sex = Column(String(10))
    email = Column(String(255), unique=True)
    contact_number = Column(String(20))
    password = Column(String(255))
    address = Column(Text)
    created_at = Column(TIMESTAMP, default=datetime.utcnow)

    issues = relationship("Issue", back_populates="citizen")
    votes = relationship("Vote", back_populates="citizen")

# %%
# Department Table
class Department(Base):
    __tablename__ = "department"
    __table_args__ = {"schema": "urbanpulse"}
    department_id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String(100), unique=True)
    budget_points = Column(DECIMAL(12, 2))
    created_at = Column(TIMESTAMP, default=datetime.utcnow)

# %%
# Official Table
class Official(Base):
    __tablename__ = "official"
    __table_args__ = {"schema": "urbanpulse"}
    official_id = Column(Integer, primary_key=True, autoincrement=True)
    first_name = Column(String(50))
    last_name = Column(String(50))
    full_name = Column(String(101))
    sex = Column(String(10))
    email = Column(String(255), unique=True)
    contact_number = Column(String(20))
    password = Column(String(255))
    address = Column(Text)
    # Fully qualify the referenced table name in the ForeignKey string:
    department_id = Column(Integer, ForeignKey("urbanpulse.department.department_id"))
    created_at = Column(TIMESTAMP, default=datetime.utcnow)

# %%
# Issue Table
class Issue(Base):
    __tablename__ = "issue"
    __table_args__ = {"schema": "urbanpulse"}
    issue_id = Column(Integer, primary_key=True, autoincrement=True)
    citizen_id = Column(Integer, ForeignKey("urbanpulse.citizen.citizen_id"))
    description = Column(Text)
    category = Column(String(50))
    priority_level = Column(Integer)
    latitude = Column(Float)
    longitude = Column(Float)
    status = Column(String(20))
    created_at = Column(TIMESTAMP, default=datetime.utcnow)

    citizen = relationship("Citizen", back_populates="issues")
    votes = relationship("Vote", back_populates="issue")

# %%
# Photo Table
class Photo(Base):
    __tablename__ = "photo"
    __table_args__ = {"schema": "urbanpulse"}
    photo_id = Column(Integer, primary_key=True, autoincrement=True)
    issue_id = Column(Integer, ForeignKey("urbanpulse.issue.issue_id"))
    photo_url = Column(String(512))
    created_at = Column(TIMESTAMP, default=datetime.utcnow)

# %%
# Vote Table
class Vote(Base):
    __tablename__ = "vote"
    __table_args__ = {"schema": "urbanpulse"}
    vote_id = Column(Integer, primary_key=True, autoincrement=True)
    citizen_id = Column(Integer, ForeignKey("urbanpulse.citizen.citizen_id"))
    issue_id = Column(Integer, ForeignKey("urbanpulse.issue.issue_id"))
    priority_vote = Column(Integer)
    created_at = Column(TIMESTAMP, default=datetime.utcnow)

    citizen = relationship("Citizen", back_populates="votes")
    issue = relationship("Issue", back_populates="votes")

# %%
# Transaction Table
class Transaction(Base):
    __tablename__ = "transaction"
    __table_args__ = {"schema": "urbanpulse"}
    transaction_id = Column(Integer, primary_key=True, autoincrement=True)
    issue_id = Column(Integer, ForeignKey("urbanpulse.issue.issue_id"))
    official_id = Column(Integer, ForeignKey("urbanpulse.official.official_id"))
    budget_spent = Column(DECIMAL(10, 2))
    status = Column(String(20))
    created_at = Column(TIMESTAMP, default=datetime.utcnow)

# %%
# Database setup
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()
# Out:
# 2025-03-03 13:22:12,697 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:22:12,698 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2025-03-03 13:22:12,698 INFO sqlalchemy.engine.Engine [generated in 0.00033s] {'table_name': 'citizen', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'urbanpulse'}
# 2025-03-03 13:22:12,879 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2025-03-03 13:22:12,880 INFO sqlalchemy.engine.Engine [cached since 0.1824s ago] {'table_name': 'department', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'urbanpulse'}
# 2025-03-03 13:22:12,971 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2025-03-03 13:22:12,972 INFO sqlalchemy.engine.Engine [cached since 0.2747s ago] {'table_name': 'official', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'urbanpulse'}
# 2025-03-03 13:22:13,063 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2025-03-03 13:22:13,064 INFO sqlalchemy.engine.Engine [cached since 0.3666s ago] {'table_name': 'issue', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'urbanpulse'}
# 2025-03-03 13:22:13,155 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2025-03-03 13:22:13,157 INFO sqlalchemy.engine.Engine [cached since 0.4589s ago] {'table_name': 'photo', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'urbanpulse'}
# 2025-03-03 13:22:13,249 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2025-03-03 13:22:13,250 INFO sqlalchemy.engine.Engine [cached since 0.5524s ago] {'table_name': 'vote', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'urbanpulse'}
# 2025-03-03 13:22:13,342 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_namespace.nspname = %(nspname_1)s
# 2025-03-03 13:22:13,344 INFO sqlalchemy.engine.Engine [cached since 0.6457s ago] {'table_name': 'transaction', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'urbanpulse'}
# 2025-03-03 13:22:13,437 INFO sqlalchemy.engine.Engine
# CREATE TABLE urbanpulse.citizen (
# 	citizen_id SERIAL NOT NULL,
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	full_name VARCHAR(101),
# 	sex VARCHAR(10),
# 	email VARCHAR(255),
# 	contact_number VARCHAR(20),
# 	password VARCHAR(255),
# 	address TEXT,
# 	created_at TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (citizen_id),
# 	UNIQUE (email)
# )
#
#
# 2025-03-03 13:22:13,440 INFO sqlalchemy.engine.Engine [no key 0.00316s] {}
# 2025-03-03 13:22:13,541 INFO sqlalchemy.engine.Engine
# CREATE TABLE urbanpulse.department (
# 	department_id SERIAL NOT NULL,
# 	name VARCHAR(100),
# 	budget_points DECIMAL(12, 2),
# 	created_at TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (department_id),
# 	UNIQUE (name)
# )
#
#
# 2025-03-03 13:22:13,543 INFO sqlalchemy.engine.Engine [no key 0.00174s] {}
# 2025-03-03 13:22:13,640 INFO sqlalchemy.engine.Engine
# CREATE TABLE urbanpulse.official (
# 	official_id SERIAL NOT NULL,
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	full_name VARCHAR(101),
# 	sex VARCHAR(10),
# 	email VARCHAR(255),
# 	contact_number VARCHAR(20),
# 	password VARCHAR(255),
# 	address TEXT,
# 	department_id INTEGER,
# 	created_at TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (official_id),
# 	UNIQUE (email),
# 	FOREIGN KEY(department_id) REFERENCES urbanpulse.department (department_id)
# )
#
#
# 2025-03-03 13:22:13,641 INFO sqlalchemy.engine.Engine [no key 0.00166s] {}
# 2025-03-03 13:22:13,740 INFO sqlalchemy.engine.Engine
# CREATE TABLE urbanpulse.issue (
# 	issue_id SERIAL NOT NULL,
# 	citizen_id INTEGER,
# 	description TEXT,
# 	category VARCHAR(50),
# 	priority_level INTEGER,
# 	latitude FLOAT,
# 	longitude FLOAT,
# 	status VARCHAR(20),
# 	created_at TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (issue_id),
# 	FOREIGN KEY(citizen_id) REFERENCES urbanpulse.citizen (citizen_id)
# )
#
#
# 2025-03-03 13:22:13,742 INFO sqlalchemy.engine.Engine [no key 0.00155s] {}
# 2025-03-03 13:22:13,839 INFO sqlalchemy.engine.Engine
# CREATE TABLE urbanpulse.photo (
# 	photo_id SERIAL NOT NULL,
# 	issue_id INTEGER,
# 	photo_url VARCHAR(255),
# 	created_at TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (photo_id),
# 	FOREIGN KEY(issue_id) REFERENCES urbanpulse.issue (issue_id)
# )
#
#
# 2025-03-03 13:22:13,841 INFO sqlalchemy.engine.Engine [no key 0.00129s] {}
# 2025-03-03 13:22:13,937 INFO sqlalchemy.engine.Engine
# CREATE TABLE urbanpulse.vote (
# 	vote_id SERIAL NOT NULL,
# 	citizen_id INTEGER,
# 	issue_id INTEGER,
# 	priority_vote INTEGER,
# 	created_at TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (vote_id),
# 	FOREIGN KEY(citizen_id) REFERENCES urbanpulse.citizen (citizen_id),
# 	FOREIGN KEY(issue_id) REFERENCES urbanpulse.issue (issue_id)
# )
#
#
# 2025-03-03 13:22:13,938 INFO sqlalchemy.engine.Engine [no key 0.00130s] {}
# 2025-03-03 13:22:14,033 INFO sqlalchemy.engine.Engine
# CREATE TABLE urbanpulse.transaction (
# 	transaction_id SERIAL NOT NULL,
# 	issue_id INTEGER,
# 	official_id INTEGER,
# 	budget_spent DECIMAL(10, 2),
# 	status VARCHAR(20),
# 	created_at TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (transaction_id),
# 	FOREIGN KEY(issue_id) REFERENCES urbanpulse.issue (issue_id),
# 	FOREIGN KEY(official_id) REFERENCES urbanpulse.official (official_id)
# )
#
#
# 2025-03-03 13:22:14,034 INFO sqlalchemy.engine.Engine [no key 0.00156s] {}
# 2025-03-03 13:22:14,129 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Sample data
# Departments
dept1 = Department(name="Infrastructure", budget_points=50000)
dept2 = Department(name="Health", budget_points=75000)

# Officials
official1 = Official(first_name="John", last_name="Doe", full_name="John Doe",
                     sex="Male", email="johndoe@email.com", contact_number="1234567890",
                     password="hashedpassword", address="City Hall, NY", department_id=1)

official2 = Official(first_name="Jane", last_name="Smith", full_name="Jane Smith",
                     sex="Female", email="janesmith@email.com", contact_number="0987654321",
                     password="hashedpassword", address="Health Office, NY", department_id=2)

# Citizens
citizen1 = Citizen(first_name="Alice", last_name="Brown", full_name="Alice Brown",
                   sex="Female", email="alice@email.com", contact_number="1112223333",
                   password="hashedpassword", address="123 Main St, NY")

citizen2 = Citizen(first_name="Bob", last_name="Miller", full_name="Bob Miller",
                   sex="Male", email="bob@email.com", contact_number="4445556666",
                   password="hashedpassword", address="456 Elm St, NY")

# Issues
issue1 = Issue(citizen_id=1, description="Broken streetlights",
               category="Infrastructure", priority_level=2, latitude=40.7128, longitude=-74.0060,
               status="Pending")

issue2 = Issue(citizen_id=2, description="Public park needs maintenance",
               category="Environment", priority_level=3, latitude=40.7138, longitude=-74.0070,
               status="Pending")

# Add parent objects first
session.add_all([
    dept1, dept2,
    official1, official2,
    citizen1, citizen2,
    issue1, issue2
])
session.flush()

# Photos
photo1 = Photo(issue_id=issue1.issue_id, photo_url="https://example.com/photo1.jpg")
photo2 = Photo(issue_id=issue2.issue_id, photo_url="https://example.com/photo2.jpg")

# Votes
vote1 = Vote(citizen_id=1, issue_id=issue1.issue_id, priority_vote=5)
vote2 = Vote(citizen_id=2, issue_id=issue2.issue_id, priority_vote=4)

# Transactions
transaction1 = Transaction(issue_id=issue1.issue_id, official_id=1, budget_spent=1000, status="Approved")
transaction2 = Transaction(issue_id=issue2.issue_id, official_id=2, budget_spent=2000, status="Pending")

# Add dependent objects
session.add_all([
    photo1, photo2,
    vote1, vote2,
    transaction1, transaction2
])
session.commit()
# Out:
# 2025-03-03 13:22:14,247 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:22:14,249 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.citizen (first_name, last_name, full_name, sex, email, contact_number, password, address, created_at) SELECT p0::VARCHAR, p1::VARCHAR, p2::VARCHAR, p3::VARCHAR, p4::VARCHAR, p5::VARCHAR, p6::VARCHAR, p7::TEXT, p8::TIMESTAMP WIT ... 418 characters truncated ...  sen_counter RETURNING urbanpulse.citizen.citizen_id, urbanpulse.citizen.citizen_id AS citizen_id__1
# 2025-03-03 13:22:14,250 INFO sqlalchemy.engine.Engine [generated in 0.00013s (insertmanyvalues) 1/1 (ordered)] {'last_name__0': 'Brown', 'first_name__0': 'Alice', 'full_name__0': 'Alice Brown', 'address__0': '123 Main St, NY', 'password__0': 'hashedpassword', 'email__0': 'alice@email.com', 'created_at__0': datetime.datetime(2025, 3, 3, 6, 22, 14, 249508), 'contact_number__0': '1112223333', 'sex__0': 'Female', 'last_name__1': 'Miller', 'first_name__1': 'Bob', 'full_name__1': 'Bob Miller', 'address__1': '456 Elm St, NY', 'password__1': 'hashedpassword', 'email__1': 'bob@email.com', 'created_at__1': datetime.datetime(2025, 3, 3, 6, 22, 14, 249512), 'contact_number__1': '4445556666', 'sex__1': 'Male'}
# 2025-03-03 13:22:14,434 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.department (name, budget_points, created_at) SELECT p0::VARCHAR, p1::NUMERIC(12, 2), p2::TIMESTAMP WITHOUT TIME ZONE FROM (VALUES (%(name__0)s, %(budget_points__0)s, %(created_at__0)s, 0), (%(name__1)s, %(budget_points__1)s, %(created_at__1)s, 1)) AS imp_sen(p0, p1, p2, sen_counter) ORDER BY sen_counter RETURNING urbanpulse.department.department_id, urbanpulse.department.department_id AS department_id__1
# 2025-03-03 13:22:14,435 INFO sqlalchemy.engine.Engine [generated in 0.00022s (insertmanyvalues) 1/1 (ordered)] {'created_at__0': datetime.datetime(2025, 3, 3, 6, 22, 14, 434275), 'name__0': 'Infrastructure', 'budget_points__0': 50000, 'created_at__1': datetime.datetime(2025, 3, 3, 6, 22, 14, 434285), 'name__1': 'Health', 'budget_points__1': 75000}
# 2025-03-03 13:22:14,540 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.official (first_name, last_name, full_name, sex, email, contact_number, password, address, department_id, created_at) SELECT p0::VARCHAR, p1::VARCHAR, p2::VARCHAR, p3::VARCHAR, p4::VARCHAR, p5::VARCHAR, p6::VARCHAR, p7::TEXT, p ... 500 characters truncated ... counter RETURNING urbanpulse.official.official_id, urbanpulse.official.official_id AS official_id__1
# 2025-03-03 13:22:14,541 INFO sqlalchemy.engine.Engine [generated in 0.00024s (insertmanyvalues) 1/1 (ordered)] {'last_name__0': 'Doe', 'first_name__0': 'John', 'full_name__0': 'John Doe', 'address__0': 'City Hall, NY', 'department_id__0': 1, 'password__0': 'hashedpassword', 'email__0': 'johndoe@email.com', 'created_at__0': datetime.datetime(2025, 3, 3, 6, 22, 14, 540093), 'contact_number__0': '1234567890', 'sex__0': 'Male', 'last_name__1': 'Smith', 'first_name__1': 'Jane', 'full_name__1': 'Jane Smith', 'address__1': 'Health Office, NY', 'department_id__1': 2, 'password__1': 'hashedpassword', 'email__1': 'janesmith@email.com', 'created_at__1': datetime.datetime(2025, 3, 3, 6, 22, 14, 540104), 'contact_number__1': '0987654321', 'sex__1': 'Female'}
# 2025-03-03 13:22:14,700 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) SELECT p0::INTEGER, p1::TEXT, p2::VARCHAR, p3::INTEGER, p4::FLOAT, p5::FLOAT, p6::VARCHAR, p7::TIMESTAMP WITHOUT TIME ZONE FROM  ... 368 characters truncated ... ) ORDER BY sen_counter RETURNING urbanpulse.issue.issue_id, urbanpulse.issue.issue_id AS issue_id__1
# 2025-03-03 13:22:14,701 INFO sqlalchemy.engine.Engine [generated in 0.00034s (insertmanyvalues) 1/1 (ordered)] {'latitude__0': 40.7128, 'category__0': 'Infrastructure', 'status__0': 'Pending', 'longitude__0': -74.006, 'priority_level__0': 2, 'citizen_id__0': 1, 'description__0': 'Broken streetlights', 'created_at__0': datetime.datetime(2025, 3, 3, 6, 22, 14, 700196), 'latitude__1': 40.7138, 'category__1': 'Environment', 'status__1': 'Pending', 'longitude__1': -74.007, 'priority_level__1': 3, 'citizen_id__1': 2, 'description__1': 'Public park needs maintenance', 'created_at__1': datetime.datetime(2025, 3, 3, 6, 22, 14, 700212)}
# 2025-03-03 13:22:14,799 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.photo (issue_id, photo_url, created_at) SELECT p0::INTEGER, p1::VARCHAR, p2::TIMESTAMP WITHOUT TIME ZONE FROM (VALUES (%(issue_id__0)s, %(photo_url__0)s, %(created_at__0)s, 0), (%(issue_id__1)s, %(photo_url__1)s, %(created_at__1)s, 1)) AS imp_sen(p0, p1, p2, sen_counter) ORDER BY sen_counter RETURNING urbanpulse.photo.photo_id, urbanpulse.photo.photo_id AS photo_id__1
# 2025-03-03 13:22:14,800 INFO sqlalchemy.engine.Engine [generated in 0.00031s (insertmanyvalues) 1/1 (ordered)] {'issue_id__0': 1, 'photo_url__0': 'https://example.com/photo1.jpg', 'created_at__0': datetime.datetime(2025, 3, 3, 6, 22, 14, 798700), 'issue_id__1': 2, 'photo_url__1': 'https://example.com/photo2.jpg', 'created_at__1': datetime.datetime(2025, 3, 3, 6, 22, 14, 798720)}
# 2025-03-03 13:22:14,895 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.transaction (issue_id, official_id, budget_spent, status, created_at) SELECT p0::INTEGER, p1::INTEGER, p2::NUMERIC(10, 2), p3::VARCHAR, p4::TIMESTAMP WITHOUT TIME ZONE FROM (VALUES (%(issue_id__0)s, %(official_id__0)s, %(budget ... 220 characters truncated ... NG urbanpulse.transaction.transaction_id, urbanpulse.transaction.transaction_id AS transaction_id__1
# 2025-03-03 13:22:14,897 INFO sqlalchemy.engine.Engine [generated in 0.00030s (insertmanyvalues) 1/1 (ordered)] {'budget_spent__0': 1000, 'status__0': 'Approved', 'issue_id__0': 1, 'official_id__0': 1, 'created_at__0': datetime.datetime(2025, 3, 3, 6, 22, 14, 895478), 'budget_spent__1': 2000, 'status__1': 'Pending', 'issue_id__1': 2, 'official_id__1': 2, 'created_at__1': datetime.datetime(2025, 3, 3, 6, 22, 14, 895493)}
# 2025-03-03 13:22:14,991 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.vote (citizen_id, issue_id, priority_vote, created_at) SELECT p0::INTEGER, p1::INTEGER, p2::INTEGER, p3::TIMESTAMP WITHOUT TIME ZONE FROM (VALUES (%(citizen_id__0)s, %(issue_id__0)s, %(priority_vote__0)s, %(created_at__0)s, 0), (%(citizen_id__1)s, %(issue_id__1)s, %(priority_vote__1)s, %(created_at__1)s, 1)) AS imp_sen(p0, p1, p2, p3, sen_counter) ORDER BY sen_counter RETURNING urbanpulse.vote.vote_id, urbanpulse.vote.vote_id AS vote_id__1
# 2025-03-03 13:22:14,993 INFO sqlalchemy.engine.Engine [generated in 0.00029s (insertmanyvalues) 1/1 (ordered)] {'issue_id__0': 1, 'citizen_id__0': 1, 'priority_vote__0': 5, 'created_at__0': datetime.datetime(2025, 3, 3, 6, 22, 14, 991365), 'issue_id__1': 2, 'citizen_id__1': 2, 'priority_vote__1': 4, 'created_at__1': datetime.datetime(2025, 3, 3, 6, 22, 14, 991381)}
# 2025-03-03 13:22:15,086 INFO sqlalchemy.engine.Engine COMMIT

# %%
def create_new_citizen(first_name, last_name, sex, email, contact_number, password, address):
    session = Session()
    citizen = Citizen(
        first_name=first_name,
        last_name=last_name,
        full_name=f"{first_name} {last_name}",
        sex=sex,
        email=email,
        contact_number=contact_number,
        password=password,
        address=address
    )
    session.add(citizen)
    session.commit()
    session.close()
    print(f"Created citizen: {citizen.full_name}")
    return citizen

# %%
def report_issue(citizen_id, description, category, priority_level, latitude, longitude, status="Pending"):
    session = Session()
    try:
        issue = Issue(
            citizen_id=citizen_id,
            description=description,
            category=category,
            priority_level=priority_level,
            latitude=latitude,
            longitude=longitude,
            status=status
        )
        session.add(issue)
        session.commit()
        issue_id = issue.issue_id  # Extract ID while session is active
        print(f"Issue reported: {description}")
        return issue_id  # Return the ID instead of the Issue object
    finally:
        session.close()

# %%
def cast_vote(citizen_id, issue_id, priority_vote):
    session = Session()
    vote = Vote(
        citizen_id=citizen_id,
        issue_id=issue_id,
        priority_vote=priority_vote
    )
    session.add(vote)
    session.commit()
    session.close()
    print(f"Vote cast on issue {issue_id} by citizen {citizen_id}")
    return vote

# %%
def process_issue_transaction(issue_id, official_id, budget_spent):
    """
    This operation processes a transaction for an issue.
    It locks the corresponding department row to ensure that the deduction from budget is atomic.
    """
    session = Session()
    try:
        official = session.query(Official).filter(Official.official_id == official_id).one()
        # Lock the department row for update to prevent race conditions
        department = session.query(Department)\
            .with_for_update()\
            .filter(Department.department_id == official.department_id)\
            .one()
        if department.budget_points < budget_spent:
            session.rollback()
            raise Exception("Not enough budget in the department.")
        # Deduct the budget points
        department.budget_points -= budget_spent
        # Create a transaction record
        transaction_record = Transaction(
            issue_id=issue_id,
            official_id=official_id,
            budget_spent=budget_spent,
            status='Approved'
        )
        session.add(transaction_record)
        session.commit()
        print(f"Processed transaction for issue {issue_id} by official {official_id}")
        return transaction_record
    except Exception as e:
        session.rollback()
        print(f"Transaction failed: {e}")
    finally:
        session.close()
    return None

# %%
# --------------------------
# Performance Test Functions
# --------------------------

def performance_test_report_issue(num_iterations=10000):
    """Test performance of reporting issues."""
    start = time.time()
    session = Session()
    citizen = session.query(Citizen).first()
    if not citizen:
        citizen = create_new_citizen("Test", "User", "Other", "testuser@example.com", "0000000000", "password", "Test Address")
    session.close()
    for i in range(num_iterations):
        report_issue(citizen.citizen_id, f"Issue {i}", "Infrastructure", 3, 12.34, 56.78)
    end = time.time()
    print(f"Performance Test - Reporting {num_iterations} issues took {end - start:.2f} seconds.")

# %%
def performance_test_cast_vote(num_iterations=10000):
    start = time.time()
    session = Session()
    citizen = session.query(Citizen).first()
    issue = session.query(Issue).first()
    if not citizen:
        citizen = create_new_citizen("Test", "User2", "Other", "testuser2@example.com", "0000000000", "password", "Test Address 2")
    if not issue:
        issue_id = report_issue(citizen.citizen_id, "Test issue for votes", "Infrastructure", 3, 12.34, 56.78)
    else:
        issue_id = issue.issue_id  # Use existing issue's ID if available
    session.close()
    for i in range(num_iterations):
        cast_vote(citizen.citizen_id, issue_id, 3)
    end = time.time()
    print(f"Performance Test - Casting {num_iterations} votes took {end - start:.2f} seconds.")

# %%
# --------------------------
# Isolation Test Function
# --------------------------

def isolation_test_process_issue_transaction():
    session = Session()
    try:
        # Query or create department
        department = session.query(Department).filter_by(name='Isolation Test Dept').first()
        if not department:
            department = Department(name='Isolation Test Dept', budget_points=1000.00)
            session.add(department)
            session.commit()

        # Query or create official
        official = session.query(Official).filter_by(email='isol@official.com').first()
        if not official:
            official = Official(
                first_name='Iso', last_name='Test', full_name='Iso Test', sex='Other',
                email='isol@official.com', contact_number='111111', password='password',
                address='Test Address', department_id=department.department_id
            )
            session.add(official)
            session.commit()

        # Query or create citizen
        citizen = session.query(Citizen).first()
        if not citizen:
            citizen = create_new_citizen("Iso", "Citizen", "Other", "iso@citizen.com", "2222222222", "password", "Test Address")

        # Report the issue and get the issue_id
        issue_id = report_issue(citizen.citizen_id, "Isolation test issue", "Infrastructure", 3, 12.34, 56.78)
        official_id = official.official_id  # Extract official ID

        # Define the wrapper function using only IDs
        def process_transaction_wrapper(budget_spent):
            return process_issue_transaction(issue_id, official_id, budget_spent)

        # Execute concurrent transactions
        with ThreadPoolExecutor(max_workers=2) as executor:
            future1 = executor.submit(process_transaction_wrapper, 700)
            future2 = executor.submit(process_transaction_wrapper, 700)
            result1 = future1.result()
            result2 = future2.result()

        # Query the updated department budget
        updated_department = session.query(Department).filter(Department.department_id == department.department_id).one()
        print(f"Isolation Test - After concurrent transactions, department budget: {updated_department.budget_points}")
        print("Isolation test completed. Only one transaction should succeed if budget is insufficient.")

    finally:
        session.close()

# %%
# Main block to run tests
if __name__ == '__main__':
    # Optional: Reset sequence or clear tables
    with engine.connect() as connection:
        connection.execute(text("SELECT setval('urbanpulse.issue_issue_id_seq', (SELECT COALESCE(MAX(issue_id), 0) + 1 FROM urbanpulse.issue))"))
        connection.commit()

    # Run performance tests
    performance_test_report_issue(num_iterations=1000)
    performance_test_cast_vote(num_iterations=1000)

    # Run isolation test
    isolation_test_process_issue_transaction()
# Out:
# 2025-03-03 13:25:10,256 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:10,258 INFO sqlalchemy.engine.Engine SELECT setval('urbanpulse.issue_issue_id_seq', (SELECT COALESCE(MAX(issue_id), 0) + 1 FROM urbanpulse.issue))
# 2025-03-03 13:25:10,259 INFO sqlalchemy.engine.Engine [cached since 175s ago] {}
# 2025-03-03 13:25:10,442 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:10,536 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:10,538 INFO sqlalchemy.engine.Engine SELECT urbanpulse.citizen.citizen_id AS urbanpulse_citizen_citizen_id, urbanpulse.citizen.first_name AS urbanpulse_citizen_first_name, urbanpulse.citizen.last_name AS urbanpulse_citizen_last_name, urbanpulse.citizen.full_name AS urbanpulse_citizen_full_name, urbanpulse.citizen.sex AS urbanpulse_citizen_sex, urbanpulse.citizen.email AS urbanpulse_citizen_email, urbanpulse.citizen.contact_number AS urbanpulse_citizen_contact_number, urbanpulse.citizen.password AS urbanpulse_citizen_password, urbanpulse.citizen.address AS urbanpulse_citizen_address, urbanpulse.citizen.created_at AS urbanpulse_citizen_created_at
# FROM urbanpulse.citizen
#  LIMIT %(param_1)s
# 2025-03-03 13:25:10,539 INFO sqlalchemy.engine.Engine [cached since 175s ago] {'param_1': 1}
# 2025-03-03 13:25:10,775 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:10,869 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:10,871 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:10,872 INFO sqlalchemy.engine.Engine [cached since 175.1s ago] {'citizen_id': 1, 'description': 'Issue 0', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 10, 871707)}
# 2025-03-03 13:25:11,054 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:11,148 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:11,150 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:11,151 INFO sqlalchemy.engine.Engine [cached since 175.1s ago] {'pk_1': 16}
# Issue reported: Issue 0
# 2025-03-03 13:25:11,362 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:11,456 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:11,458 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:11,459 INFO sqlalchemy.engine.Engine [cached since 175.7s ago] {'citizen_id': 1, 'description': 'Issue 1', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 11, 458695)}
# 2025-03-03 13:25:11,644 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:11,747 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:11,749 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:11,750 INFO sqlalchemy.engine.Engine [cached since 175.7s ago] {'pk_1': 17}
# Issue reported: Issue 1
# 2025-03-03 13:25:11,933 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:12,028 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:12,030 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:12,031 INFO sqlalchemy.engine.Engine [cached since 176.3s ago] {'citizen_id': 1, 'description': 'Issue 2', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 12, 30527)}
# 2025-03-03 13:25:12,216 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:12,311 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:12,312 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:12,313 INFO sqlalchemy.engine.Engine [cached since 176.2s ago] {'pk_1': 18}
# Issue reported: Issue 2
# 2025-03-03 13:25:12,498 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:12,591 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:12,594 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:12,595 INFO sqlalchemy.engine.Engine [cached since 176.8s ago] {'citizen_id': 1, 'description': 'Issue 3', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 12, 594064)}
# 2025-03-03 13:25:12,777 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:12,870 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:12,872 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:12,873 INFO sqlalchemy.engine.Engine [cached since 176.8s ago] {'pk_1': 19}
# Issue reported: Issue 3
# 2025-03-03 13:25:13,056 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:13,149 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:13,151 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:13,152 INFO sqlalchemy.engine.Engine [cached since 177.4s ago] {'citizen_id': 1, 'description': 'Issue 4', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 13, 151903)}
# 2025-03-03 13:25:13,337 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:13,430 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:13,433 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:13,434 INFO sqlalchemy.engine.Engine [cached since 177.3s ago] {'pk_1': 20}
# Issue reported: Issue 4
# 2025-03-03 13:25:13,615 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:13,707 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:13,709 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:13,710 INFO sqlalchemy.engine.Engine [cached since 177.9s ago] {'citizen_id': 1, 'description': 'Issue 5', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 13, 709431)}
# 2025-03-03 13:25:13,894 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:13,988 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:13,990 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:13,991 INFO sqlalchemy.engine.Engine [cached since 177.9s ago] {'pk_1': 21}
# Issue reported: Issue 5
# 2025-03-03 13:25:14,201 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:14,302 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:14,304 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:14,305 INFO sqlalchemy.engine.Engine [cached since 178.5s ago] {'citizen_id': 1, 'description': 'Issue 6', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 14, 304230)}
# 2025-03-03 13:25:14,486 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:14,579 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:14,581 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:14,581 INFO sqlalchemy.engine.Engine [cached since 178.5s ago] {'pk_1': 22}
# Issue reported: Issue 6
# 2025-03-03 13:25:14,795 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:14,888 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:14,889 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:14,890 INFO sqlalchemy.engine.Engine [cached since 179.1s ago] {'citizen_id': 1, 'description': 'Issue 7', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 14, 889923)}
# 2025-03-03 13:25:15,123 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:15,218 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:15,220 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:15,221 INFO sqlalchemy.engine.Engine [cached since 179.1s ago] {'pk_1': 23}
# Issue reported: Issue 7
# 2025-03-03 13:25:15,401 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:15,493 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:15,495 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:15,496 INFO sqlalchemy.engine.Engine [cached since 179.7s ago] {'citizen_id': 1, 'description': 'Issue 8', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 15, 495361)}
# 2025-03-03 13:25:15,704 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:15,798 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:15,799 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:15,800 INFO sqlalchemy.engine.Engine [cached since 179.7s ago] {'pk_1': 24}
# Issue reported: Issue 8
# 2025-03-03 13:25:16,004 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:16,098 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:16,100 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:16,101 INFO sqlalchemy.engine.Engine [cached since 180.3s ago] {'citizen_id': 1, 'description': 'Issue 9', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 16, 100363)}
# 2025-03-03 13:25:16,282 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:16,374 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:16,375 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:16,376 INFO sqlalchemy.engine.Engine [cached since 180.3s ago] {'pk_1': 25}
# Issue reported: Issue 9
# 2025-03-03 13:25:16,559 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:16,653 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:16,655 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:16,656 INFO sqlalchemy.engine.Engine [cached since 180.9s ago] {'citizen_id': 1, 'description': 'Issue 10', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 16, 655202)}
# 2025-03-03 13:25:16,840 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:16,935 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:16,937 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:16,937 INFO sqlalchemy.engine.Engine [cached since 180.8s ago] {'pk_1': 26}
# Issue reported: Issue 10
# 2025-03-03 13:25:17,120 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:17,211 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:17,212 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:17,213 INFO sqlalchemy.engine.Engine [cached since 181.4s ago] {'citizen_id': 1, 'description': 'Issue 11', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 17, 212829)}
# 2025-03-03 13:25:17,396 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:17,490 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:17,492 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:17,493 INFO sqlalchemy.engine.Engine [cached since 181.4s ago] {'pk_1': 27}
# Issue reported: Issue 11
# 2025-03-03 13:25:17,680 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:17,776 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:17,778 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:17,779 INFO sqlalchemy.engine.Engine [cached since 182s ago] {'citizen_id': 1, 'description': 'Issue 12', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 17, 778283)}
# 2025-03-03 13:25:17,964 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:18,058 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:18,060 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:18,061 INFO sqlalchemy.engine.Engine [cached since 182s ago] {'pk_1': 28}
# Issue reported: Issue 12
# 2025-03-03 13:25:18,245 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:18,338 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:18,340 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:18,341 INFO sqlalchemy.engine.Engine [cached since 182.6s ago] {'citizen_id': 1, 'description': 'Issue 13', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 18, 340567)}
# 2025-03-03 13:25:18,525 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:18,620 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:18,622 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:18,623 INFO sqlalchemy.engine.Engine [cached since 182.5s ago] {'pk_1': 29}
# Issue reported: Issue 13
# 2025-03-03 13:25:18,804 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:18,895 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:18,897 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:18,898 INFO sqlalchemy.engine.Engine [cached since 183.1s ago] {'citizen_id': 1, 'description': 'Issue 14', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 18, 897503)}
# 2025-03-03 13:25:19,082 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:19,177 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:19,178 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:19,179 INFO sqlalchemy.engine.Engine [cached since 183.1s ago] {'pk_1': 30}
# Issue reported: Issue 14
# 2025-03-03 13:25:19,363 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:19,456 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:19,458 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:19,459 INFO sqlalchemy.engine.Engine [cached since 183.7s ago] {'citizen_id': 1, 'description': 'Issue 15', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 19, 458385)}
# 2025-03-03 13:25:19,639 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:19,732 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:19,734 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:19,735 INFO sqlalchemy.engine.Engine [cached since 183.6s ago] {'pk_1': 31}
# Issue reported: Issue 15
# 2025-03-03 13:25:19,919 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:20,011 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:20,013 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:20,014 INFO sqlalchemy.engine.Engine [cached since 184.2s ago] {'citizen_id': 1, 'description': 'Issue 16', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 20, 13556)}
# 2025-03-03 13:25:20,198 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:20,292 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:20,293 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:20,294 INFO sqlalchemy.engine.Engine [cached since 184.2s ago] {'pk_1': 32}
# Issue reported: Issue 16
# 2025-03-03 13:25:20,475 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:20,567 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:20,569 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:20,570 INFO sqlalchemy.engine.Engine [cached since 184.8s ago] {'citizen_id': 1, 'description': 'Issue 17', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 20, 569326)}
# 2025-03-03 13:25:20,755 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:20,848 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:20,850 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:20,851 INFO sqlalchemy.engine.Engine [cached since 184.8s ago] {'pk_1': 33}
# Issue reported: Issue 17
# 2025-03-03 13:25:21,054 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:21,147 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:21,148 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:21,149 INFO sqlalchemy.engine.Engine [cached since 185.4s ago] {'citizen_id': 1, 'description': 'Issue 18', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 21, 148927)}
# 2025-03-03 13:25:21,331 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:21,423 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:21,425 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:21,426 INFO sqlalchemy.engine.Engine [cached since 185.3s ago] {'pk_1': 34}
# Issue reported: Issue 18
# 2025-03-03 13:25:21,671 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:21,764 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:21,765 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:21,766 INFO sqlalchemy.engine.Engine [cached since 186s ago] {'citizen_id': 1, 'description': 'Issue 19', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 21, 765386)}
# 2025-03-03 13:25:21,949 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:22,043 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:22,045 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:22,046 INFO sqlalchemy.engine.Engine [cached since 186s ago] {'pk_1': 35}
# Issue reported: Issue 19
# 2025-03-03 13:25:22,227 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:22,320 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:22,321 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:22,322 INFO sqlalchemy.engine.Engine [cached since 186.5s ago] {'citizen_id': 1, 'description': 'Issue 20', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 22, 321446)}
# 2025-03-03 13:25:22,506 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:22,600 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:22,601 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:22,602 INFO sqlalchemy.engine.Engine [cached since 186.5s ago] {'pk_1': 36}
# Issue reported: Issue 20
# 2025-03-03 13:25:22,816 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:22,909 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:22,911 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:22,912 INFO sqlalchemy.engine.Engine [cached since 187.1s ago] {'citizen_id': 1, 'description': 'Issue 21', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 22, 911481)}
# 2025-03-03 13:25:23,093 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:23,186 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:23,188 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:23,189 INFO sqlalchemy.engine.Engine [cached since 187.1s ago] {'pk_1': 37}
# Issue reported: Issue 21
# 2025-03-03 13:25:23,389 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:23,482 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:23,484 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:23,485 INFO sqlalchemy.engine.Engine [cached since 187.7s ago] {'citizen_id': 1, 'description': 'Issue 22', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 23, 484486)}
# 2025-03-03 13:25:23,675 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:23,768 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:23,770 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:23,771 INFO sqlalchemy.engine.Engine [cached since 187.7s ago] {'pk_1': 38}
# Issue reported: Issue 22
# 2025-03-03 13:25:23,953 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:24,046 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:24,048 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:24,049 INFO sqlalchemy.engine.Engine [cached since 188.3s ago] {'citizen_id': 1, 'description': 'Issue 23', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 24, 47966)}
# 2025-03-03 13:25:24,233 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:24,327 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:24,329 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:24,330 INFO sqlalchemy.engine.Engine [cached since 188.2s ago] {'pk_1': 39}
# Issue reported: Issue 23
# 2025-03-03 13:25:24,515 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:24,608 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:24,610 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:24,610 INFO sqlalchemy.engine.Engine [cached since 188.8s ago] {'citizen_id': 1, 'description': 'Issue 24', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 24, 610132)}
# 2025-03-03 13:25:24,791 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:24,883 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:24,885 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:24,885 INFO sqlalchemy.engine.Engine [cached since 188.8s ago] {'pk_1': 40}
# Issue reported: Issue 24
# 2025-03-03 13:25:25,069 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:25,161 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:25,163 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:25,164 INFO sqlalchemy.engine.Engine [cached since 189.4s ago] {'citizen_id': 1, 'description': 'Issue 25', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 25, 163775)}
# 2025-03-03 13:25:25,348 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:25,441 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:25,443 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:25,444 INFO sqlalchemy.engine.Engine [cached since 189.4s ago] {'pk_1': 41}
# Issue reported: Issue 25
# 2025-03-03 13:25:25,626 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:25,718 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:25,720 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:25,721 INFO sqlalchemy.engine.Engine [cached since 189.9s ago] {'citizen_id': 1, 'description': 'Issue 26', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 25, 720890)}
# 2025-03-03 13:25:25,905 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:25,998 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:26,000 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:26,000 INFO sqlalchemy.engine.Engine [cached since 189.9s ago] {'pk_1': 42}
# Issue reported: Issue 26
# 2025-03-03 13:25:26,215 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:26,309 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:26,311 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:26,312 INFO sqlalchemy.engine.Engine [cached since 190.5s ago] {'citizen_id': 1, 'description': 'Issue 27', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 26, 311491)}
# 2025-03-03 13:25:26,494 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:26,586 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...
# Issue reported: Issue 59
# 2025-03-03 13:25:44,882 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:44,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:44,981 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:44,982 INFO sqlalchemy.engine.Engine [cached since 209.2s ago] {'citizen_id': 1, 'description': 'Issue 60', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 44, 981589)}
# 2025-03-03 13:25:45,164 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:45,256 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:45,258 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:45,259 INFO sqlalchemy.engine.Engine [cached since 209.2s ago] {'pk_1': 76}
# Issue reported: Issue 60
# 2025-03-03 13:25:45,443 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:45,537 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:45,539 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:45,540 INFO sqlalchemy.engine.Engine [cached since 209.8s ago] {'citizen_id': 1, 'description': 'Issue 61', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 45, 539120)}
# 2025-03-03 13:25:45,725 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:45,819 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:45,822 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:45,823 INFO sqlalchemy.engine.Engine [cached since 209.7s ago] {'pk_1': 77}
# Issue reported: Issue 61
# 2025-03-03 13:25:46,005 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:46,097 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:46,099 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:46,100 INFO sqlalchemy.engine.Engine [cached since 210.3s ago] {'citizen_id': 1, 'description': 'Issue 62', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 46, 99298)}
# 2025-03-03 13:25:46,291 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:46,387 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:46,389 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:46,390 INFO sqlalchemy.engine.Engine [cached since 210.3s ago] {'pk_1': 78}
# Issue reported: Issue 62
# 2025-03-03 13:25:46,574 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:46,667 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:46,669 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:46,670 INFO sqlalchemy.engine.Engine [cached since 210.9s ago] {'citizen_id': 1, 'description': 'Issue 63', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 46, 669353)}
# 2025-03-03 13:25:46,852 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:46,944 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:46,945 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:46,946 INFO sqlalchemy.engine.Engine [cached since 210.9s ago] {'pk_1': 79}
# Issue reported: Issue 63
# 2025-03-03 13:25:47,131 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:47,224 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:47,226 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:47,227 INFO sqlalchemy.engine.Engine [cached since 211.5s ago] {'citizen_id': 1, 'description': 'Issue 64', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 47, 226283)}
# 2025-03-03 13:25:47,411 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:47,506 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:47,508 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:47,509 INFO sqlalchemy.engine.Engine [cached since 211.4s ago] {'pk_1': 80}
# Issue reported: Issue 64
# 2025-03-03 13:25:47,691 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:47,783 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:47,784 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:47,785 INFO sqlalchemy.engine.Engine [cached since 212s ago] {'citizen_id': 1, 'description': 'Issue 65', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 47, 784563)}
# 2025-03-03 13:25:47,984 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:48,076 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:48,078 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:48,078 INFO sqlalchemy.engine.Engine [cached since 212s ago] {'pk_1': 81}
# Issue reported: Issue 65
# 2025-03-03 13:25:48,263 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:48,356 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:48,357 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:48,358 INFO sqlalchemy.engine.Engine [cached since 212.6s ago] {'citizen_id': 1, 'description': 'Issue 66', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 48, 357826)}
# 2025-03-03 13:25:48,539 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:48,630 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:48,632 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:48,633 INFO sqlalchemy.engine.Engine [cached since 212.5s ago] {'pk_1': 82}
# Issue reported: Issue 66
# 2025-03-03 13:25:48,817 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:48,910 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:48,912 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:48,913 INFO sqlalchemy.engine.Engine [cached since 213.1s ago] {'citizen_id': 1, 'description': 'Issue 67', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 48, 912492)}
# 2025-03-03 13:25:49,098 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:49,240 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:49,243 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:49,244 INFO sqlalchemy.engine.Engine [cached since 213.2s ago] {'pk_1': 83}
# Issue reported: Issue 67
# 2025-03-03 13:25:49,427 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:49,520 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:49,522 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:49,523 INFO sqlalchemy.engine.Engine [cached since 213.8s ago] {'citizen_id': 1, 'description': 'Issue 68', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 49, 522449)}
# 2025-03-03 13:25:49,721 INFO sqlalchemy.engine.Engine COMMIT
# 2025-03-03 13:25:49,815 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:49,818 INFO sqlalchemy.engine.Engine SELECT urbanpulse.issue.issue_id AS urbanpulse_issue_issue_id, urbanpulse.issue.citizen_id AS urbanpulse_issue_citizen_id, urbanpulse.issue.description AS urbanpulse_issue_description, urbanpulse.issue.category AS urbanpulse_issue_category, urbanpulse.issue.priority_level AS urbanpulse_issue_priority_level, urbanpulse.issue.latitude AS urbanpulse_issue_latitude, urbanpulse.issue.longitude AS urbanpulse_issue_longitude, urbanpulse.issue.status AS urbanpulse_issue_status, urbanpulse.issue.created_at AS urbanpulse_issue_created_at
# FROM urbanpulse.issue
# WHERE urbanpulse.issue.issue_id = %(pk_1)s
# 2025-03-03 13:25:49,819 INFO sqlalchemy.engine.Engine [cached since 213.7s ago] {'pk_1': 84}
# Issue reported: Issue 68
# 2025-03-03 13:25:50,005 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-03 13:25:50,098 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-03 13:25:50,100 INFO sqlalchemy.engine.Engine INSERT INTO urbanpulse.issue (citizen_id, description, category, priority_level, latitude, longitude, status, created_at) VALUES (%(citizen_id)s, %(description)s, %(category)s, %(priority_level)s, %(latitude)s, %(longitude)s, %(status)s, %(created_at)s) RETURNING urbanpulse.issue.issue_id
# 2025-03-03 13:25:50,101 INFO sqlalchemy.engine.Engine [cached since 214.3s ago] {'citizen_id': 1, 'description': 'Issue 69', 'category': 'Infrastructure', 'priority_level': 3, 'latitude': 12.34, 'longitude': 56.78, 'status': 'Pending', 'created_at': datetime.datetime(2025, 3, 3, 6, 25, 50, 100449)}
