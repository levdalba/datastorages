# %% [markdown]
# # Extract Data from Task 2 and Task 3 Databases
# ## Task 2: SQL Database (OLTP)

# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# Load database URL from .env
load_dotenv()
database_url = os.getenv("DATABASE_URL")
engine = create_engine(database_url, echo=False)

# Fetch data from Issue table
def fetch_sql_issues():
    query = "SELECT issue_id, description, category, priority_level, status FROM urbanpulse.issue"
    return pd.read_sql(query, engine)

# Fetch data from Vote table
def fetch_sql_votes():
    query = "SELECT vote_id, citizen_id, issue_id, priority_vote FROM urbanpulse.vote"
    return pd.read_sql(query, engine)

# %% [markdown]
# ## Task 3: Redis Database

# %%
import redis
import uuid

# Redis connection setup (assumes .env variables are set)
pool = redis.ConnectionPool(
    host=os.getenv('REDIS_HOST'),
    port=int(os.getenv('REDIS_PORT')),
    username=os.getenv('REDIS_USERNAME'),
    password=os.getenv('REDIS_PASSWORD'),
    decode_responses=True
)
r = redis.Redis(connection_pool=pool)

# Fetch Redis issues with vote totals
def fetch_redis_issues():
    issue_keys = r.keys("issue:*")
    issues = []
    for key in issue_keys:
        if not key.endswith(":votes"):
            issue_data = r.hgetall(key)
            issue_id = key.split(":")[1]
            vote_key = f"issue:{issue_id}:votes"
            total_votes = r.hget(vote_key, "total_votes") or 0
            issue_data['issue_id'] = issue_id
            issue_data['total_votes'] = int(total_votes)
            issues.append(issue_data)
    
    return pd.DataFrame(issues)

# %%
fetch_redis_issues()

# %% [markdown]
# ## Snowflake Setup and Data Loading

# %%
import snowflake.connector
from snowflake.connector.pandas_tools import write_pandas

# Snowflake connection
conn = snowflake.connector.connect(
    user=os.getenv('SNOWFLAKE_USER'),
    password=os.getenv('SNOWFLAKE_PASSWORD'),
    account=os.getenv('SNOWFLAKE_ACCOUNT'),
    warehouse=os.getenv('SNOWFLAKE_WAREHOUSE'),
    database=os.getenv('SNOWFLAKE_DATABASE'),
    schema=os.getenv('SNOWFLAKE_SCHEMA'),
    ocsp_fail_open=False
)


# Load data into Snowflake
def load_to_snowflake(df, table_name):
    cursor = conn.cursor()
    cursor.execute(f"TRUNCATE TABLE {table_name}")  # Clear existing data
    success, nchunks, nrows, _ = write_pandas(conn, df, table_name.upper())
    print(f"Loaded {nrows} rows into {table_name}")
    cursor.close()

# %%
# Execute setup and initial load
sql_issues = fetch_sql_issues()
sql_issues
# Out:
#       issue_id                    description        category  priority_level  \
# 0            1            Broken streetlights  Infrastructure               2
# 1            2  Public park needs maintenance     Environment               3
# 2            4                        Issue 0  Infrastructure               3
# 3            5                        Issue 1  Infrastructure               3
# 4            6                        Issue 2  Infrastructure               3
# ...        ...                            ...             ...             ...
# 1009      1012                      Issue 996  Infrastructure               3
# 1010      1013                      Issue 997  Infrastructure               3
# 1011      1014                      Issue 998  Infrastructure               3
# 1012      1015                      Issue 999  Infrastructure               3
# 1013      1016           Isolation test issue  Infrastructure               3
#
#        status
# 0     Pending
# 1     Pending
# 2     Pending
# 3     Pending
# 4     Pending
# ...       ...
# 1009  Pending
# 1010  Pending
# 1011  Pending
# 1012  Pending
# 1013  Pending
#
# [1014 rows x 5 columns]

# %%
sql_votes = fetch_sql_votes()
sql_votes
# Out:
#       vote_id  citizen_id  issue_id  priority_vote
# 0           1           1         1              5
# 1           2           2         2              4
# 2           3           1         1              3
# 3           4           1         1              3
# 4           5           1         1              3
# ...       ...         ...       ...            ...
# 1007     1003           1         1              3
# 1008     1005           1         1              3
# 1009     1007           1         1              3
# 1010     1009           1         1              3
# 1011     1011           1         1              3
#
# [1012 rows x 4 columns]

# %%
redis_issues = fetch_redis_issues()
redis_issues
# Out:
#                                 issue_id  \
# 0   b0d3a690-2ded-4260-84ae-4a21b4c006fd
# 1   5649a175-2bc5-4a0c-bf47-6e33ba649063
# 2   c1767261-e7e5-42d5-bcca-6ca927834196
# 3   86210901-c5c5-44aa-af85-67640d311197
# 4   3ed696e1-0c6d-4d10-98c0-eb0027a90e65
# ..                                   ...
# 90  416c66a1-b05d-40ed-9ae2-428436e25e64
# 91  7a6aaa08-974b-4cc5-adc8-a9a594905686
# 92  878c6cfc-76ca-4756-9d89-9aeb22e06034
# 93  9eb3f5d0-ddf5-45dc-87ee-add1f4d961ce
# 94  f4070635-e5cb-4319-ad8f-7c1f3d28eeb1
#
#                               citizen_id                description  \
# 0   cffc0f89-a0dd-4f4f-942f-e63dd0e1341f                 Issue 8545
# 1   c7b490e4-eefb-4243-b958-fb88ada8e532                 Issue 2224
# 2   db3b7996-7bae-48a1-96b6-de272bb61dc4                 Issue 7647
# 3   a6a58143-752d-48cd-87e7-dde2baed90a1                  Issue 700
# 4   5bb20832-e67a-46c8-b75a-eb604c896d84                 Issue 1975
# ..                                   ...                        ...
# 90  9ca397c6-4649-4c1a-b786-616aeb8d892d                 Issue 7623
# 91  f3a8a9f0-cc9f-47c3-953b-350130142d19                 Issue 4480
# 92  9519e5c1-7378-4aa0-9f5d-d56eeed7530f                 Issue 3626
# 93                                   NaN  Description for issue 587
# 94  77c9ea72-5a28-4db7-ac87-0c1acfc63062                 Issue 1808
#
#           category priority_level latitude longitude    status  \
# 0   Infrastructure              1    12.34     56.78  Resolved
# 1   Infrastructure              1    12.34     56.78  Resolved
# 2   Infrastructure              1    12.34     56.78  Resolved
# 3   Infrastructure              1    12.34     56.78  Resolved
# 4   Infrastructure              1    12.34     56.78  Resolved
# ..             ...            ...      ...       ...       ...
# 90  Infrastructure              1    12.34     56.78  Resolved
# 91  Infrastructure              1    12.34     56.78  Resolved
# 92  Infrastructure              1    12.34     56.78  Resolved
# 93             NaN            NaN      NaN       NaN       NaN
# 94  Infrastructure              1    12.34     56.78  Resolved
#
#             created_at  total_votes              title         expires_at
# 0    1741180087.749919            0                NaN                NaN
# 1    1741180015.620401            0                NaN                NaN
# 2    1741180077.504979            0                NaN                NaN
# 3    1741179998.206822            0                NaN                NaN
# 4    1741180012.762829            0                NaN                NaN
# ..                 ...          ...                ...                ...
# 90  1741180077.2281191            0                NaN                NaN
# 91  1741180041.3572428            0                NaN                NaN
# 92   1741180031.609694            0                NaN                NaN
# 93                 NaN            0  Traffic Issue 587  1741671479.581232
# 94   1741180010.866405            0                NaN                NaN
#
# [95 rows x 12 columns]

# %%
load_to_snowflake(sql_issues, 'sql_issues')
load_to_snowflake(sql_votes, 'sql_votes')
load_to_snowflake(redis_issues, 'redis_issues')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 load_to_snowflake(sql_issues, 'sql_issues')
#       2 load_to_snowflake(sql_votes, 'sql_votes')
#       3 load_to_snowflake(redis_issues, 'redis_issues')
#
# Cell In[7], line 19, in load_to_snowflake(df, table_name)
#      17 def load_to_snowflake(df, table_name):
#      18     cursor = conn.cursor()
# ---> 19     cursor.execute(f"TRUNCATE TABLE {table_name}")  # Clear existing data
#      20     success, nchunks, nrows, _ = write_pandas(conn, df, table_name.upper())
#      21     print(f"Loaded {nrows} rows into {table_name}")
#
# File /opt/anaconda3/lib/python3.12/site-packages/snowflake/connector/cursor.py:1104, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1100     is_integrity_error = (
#    1101         code == "100072"
#    1102     )  # NULL result in a non-nullable column
#    1103     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1104     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1105 return self
#
# File /opt/anaconda3/lib/python3.12/site-packages/snowflake/connector/errors.py:283, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     260 @staticmethod
#     261 def errorhandler_wrapper(
#     262     connection: SnowflakeConnection | None,
#    (...)    265     error_value: dict[str, Any],
#     266 ) -> None:
#     267     """Error handler wrapper that calls the errorhandler method.
#     268
#     269     Args:
#    (...)    280         exception to the first handler in that order.
#     281     """
# --> 283     handed_over = Error.hand_to_other_handler(
#     284         connection,
#     285         cursor,
#     286         error_class,
#     287         error_value,
#     288     )
#     289     if not handed_over:
#     290         raise Error.errorhandler_make_exception(
#     291             error_class,
#     292             error_value,
#     293         )
#
# File /opt/anaconda3/lib/python3.12/site-packages/snowflake/connector/errors.py:338, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     336 if cursor is not None:
#     337     cursor.messages.append((error_class, error_value))
# --> 338     cursor.errorhandler(connection, cursor, error_class, error_value)
#     339     return True
#     340 elif connection is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/snowflake/connector/errors.py:214, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     212 errno = error_value.get("errno")
#     213 done_format_msg = error_value.get("done_format_msg")
# --> 214 raise error_class(
#     215     msg=error_value.get("msg"),
#     216     errno=None if errno is None else int(errno),
#     217     sqlstate=error_value.get("sqlstate"),
#     218     sfqid=error_value.get("sfqid"),
#     219     query=error_value.get("query"),
#     220     done_format_msg=(
#     221         None if done_format_msg is None else bool(done_format_msg)
#     222     ),
#     223     connection=connection,
#     224     cursor=cursor,
#     225 )
#
# ProgrammingError: 090105 (22000): Cannot perform TRUNCATE. This session does not have a current database. Call 'USE DATABASE', or use a qualified name.
